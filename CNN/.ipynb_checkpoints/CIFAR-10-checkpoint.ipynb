# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, Dropout
from tensorflow.keras.models import Model, Sequential

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
plt.figure(figsize=(20,10))

for i in range (7):
    plt.subplot(330+i+1)
    plt.imshow(x_train[i])
    
plt.show()

# %%
print(x_train.shape, x_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)

# %%
from keras.utils import np_utils
cat_Y = np_utils.to_categorical(y_train)
num_classes = cat_Y.shape[1]
print('# of classes: ', num_classes)
# Out:
# # of classes:  10

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %% [markdown]
# # Build the model

# %%
model = Sequential()
model.add(Input(shape=x_train[1].shape))
model.add(Conv2D(filters=32, kernel_size=(3,3), strides=2, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=2, padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=2, padding='same', activation='relu'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(units=512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=num_classes, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 77s 46ms/step - loss: 1.7247 - accuracy: 0.3642 - val_loss: 1.2407 - val_accuracy: 0.5549
# Epoch 2/15
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.1964 - accuracy: 0.5736 - val_loss: 1.0580 - val_accuracy: 0.6183
# Epoch 3/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 1.0116 - accuracy: 0.6395 - val_loss: 0.9843 - val_accuracy: 0.6455
# Epoch 4/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.8692 - accuracy: 0.6912 - val_loss: 0.9238 - val_accuracy: 0.6692
# Epoch 5/15
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.7690 - accuracy: 0.7258 - val_loss: 0.8850 - val_accuracy: 0.6868
# Epoch 6/15
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.6718 - accuracy: 0.7634 - val_loss: 0.8822 - val_accuracy: 0.6961
# Epoch 7/15
# 1563/1563 [==============================] - 56s 36ms/step - loss: 0.5785 - accuracy: 0.7944 - val_loss: 0.9239 - val_accuracy: 0.6898
# Epoch 8/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.5042 - accuracy: 0.8199 - val_loss: 0.9272 - val_accuracy: 0.6994
# Epoch 9/15
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.4547 - accuracy: 0.8406 - val_loss: 0.9518 - val_accuracy: 0.6964
# Epoch 10/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.4006 - accuracy: 0.8558 - val_loss: 0.9646 - val_accuracy: 0.6954
# Epoch 11/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.3595 - accuracy: 0.8726 - val_loss: 1.0317 - val_accuracy: 0.6993
# Epoch 12/15
# 1563/1563 [==============================] - 52s 34ms/step - loss: 0.3221 - accuracy: 0.8845 - val_loss: 1.0753 - val_accuracy: 0.6858
# Epoch 13/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.2957 - accuracy: 0.8957 - val_loss: 1.0441 - val_accuracy: 0.6972
# Epoch 14/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.2831 - accuracy: 0.8993 - val_loss: 1.0961 - val_accuracy: 0.6933
# Epoch 15/15
# 1563/1563 [==============================] - 52s 34ms/step - loss: 0.2766 - accuracy: 0.9034 - val_loss: 1.1303 - val_accuracy: 0.6984

# %%
plt.figure(0)
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# C:\Users\User\anaconda3\envs\test\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\User\anaconda3\envs\test\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# Confusion matrix, without normalization
# [[723  14  51  31  24   9   4  10  99  35]
#  [ 21 814  13  10   1   4   5   6  52  74]
#  [ 57   4 605  78  97  51  51  29  20   8]
#  [ 17  11  83 507  62 180  54  43  21  22]
#  [ 23   2  99  58 650  45  42  70   8   3]
#  [  8   8  50 182  48 585  42  59   8  10]
#  [  8   7  47  74  59  49 733   7   8   8]
#  [ 17   5  48  38  56  37   2 779   1  17]
#  [ 54  23  19  15  12   6   6   3 849  13]
#  [ 40 119  10  13   2  15   6  20  36 739]]

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i])
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-608b5ebada70> in <module>
#       4 i = np.random.choice(misclassified_idx)
#       5 plt.imshow(x_test[i])
# ----> 6 plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]))
#
# TypeError: only integer scalar arrays can be converted to a scalar index
