# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.figure(0)
plt.imshow(x_train[1], cmap='gray')
plt.figure(1)
plt.imshow(x_train[9], cmap='gray')
plt.figure(2)
plt.imshow(x_train[45], cmap='gray')

# %%
print('train: ', x_train.shape , ' test: ', x_test.shape)
# Out:
# train:  (60000, 28, 28)  test:  (10000, 28, 28)

# %%
x_train = x_train/255

# %%
x_test = x_test/255

# %% [markdown]
# # Building the model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=10, activation='softmax')    
])

# %%
# the loss is bc od one hot encoding
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
history = model.fit(x=x_train, y=y_train, validation_data=(x_test, y_test), epochs=11)
# Out:
# Epoch 1/11
# 1875/1875 [==============================] - 23s 8ms/step - loss: 0.4735 - accuracy: 0.8629 - val_loss: 0.1369 - val_accuracy: 0.9592
# Epoch 2/11
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1513 - accuracy: 0.9551 - val_loss: 0.1020 - val_accuracy: 0.9699
# Epoch 3/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1134 - accuracy: 0.9655 - val_loss: 0.0859 - val_accuracy: 0.9737
# Epoch 4/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0882 - accuracy: 0.9730 - val_loss: 0.0829 - val_accuracy: 0.9751
# Epoch 5/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0774 - accuracy: 0.9749 - val_loss: 0.0751 - val_accuracy: 0.9768
# Epoch 6/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0634 - accuracy: 0.9796 - val_loss: 0.0688 - val_accuracy: 0.9792
# Epoch 7/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0578 - accuracy: 0.9816 - val_loss: 0.0758 - val_accuracy: 0.9779
# Epoch 8/11
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0507 - accuracy: 0.9836 - val_loss: 0.0707 - val_accuracy: 0.9785
# Epoch 9/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0448 - accuracy: 0.9851 - val_loss: 0.0734 - val_accuracy: 0.9773
# Epoch 10/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0408 - accuracy: 0.9867 - val_loss: 0.0709 - val_accuracy: 0.9788
# Epoch 11/11
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0394 - accuracy: 0.9867 - val_loss: 0.0692 - val_accuracy: 0.9809

# %%
plt.figure(0)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluating the model

# %%
model.evaluate(x=x_test, y= y_test)
# Out:
# 313/313 [==============================] - 4s 995us/step - loss: 0.0692 - accuracy: 0.9809
# [0.06924207508563995, 0.98089998960495]

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
    if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
    else:
      print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix, without normalization
# [[ 973    0    2    0    0    0    1    1    3    0]
#  [   0 1123    3    2    0    0    1    2    4    0]
#  [   1    1 1014    4    1    0    1    5    5    0]
#  [   1    0    2  995    0    4    0    4    4    0]
#  [   0    0    4    0  964    0    3    2    2    7]
#  [   2    1    0    8    1  870    3    0    6    1]
#  [   4    3    1    1    4    3  939    0    3    0]
#  [   2    6   10    1    3    0    0  997    4    5]
#  [   3    1    2    2    2    1    1    5  956    1]
#  [   0    3    0    9    9    4    1    3    2  978]]

# %%
# Show some misclassified examples
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (y_test[i], p_test[i]));
